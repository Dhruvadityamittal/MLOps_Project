# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Load data

# %%
data_path = "data/dataset/iteration1_train_data.csv"
label_path = "data/dataset/iteration1_label_data.csv"

# %%
X = pd.read_csv(Path().cwd().parent/data_path)
y = pd.read_csv(Path().cwd().parent/label_path)

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        13.85         19.60           88.68      592.6          0.08684
# 1        16.26         21.88          107.50      826.8          0.11650
# 2        10.51         23.09           66.85      334.2          0.10150
# 3        20.94         23.56          138.90     1364.0          0.10070
# 4        12.80         17.46           83.05      508.3          0.08044
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.06330         0.01342              0.02293         0.1555
# 1           0.12830         0.17990              0.07981         0.1869
# 2           0.06797         0.02495              0.01875         0.1695
# 3           0.16060         0.27120              0.13100         0.2205
# 4           0.08895         0.07390              0.04083         0.1574
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
X.to_numpy().shape
# Out:
# (554, 30)
